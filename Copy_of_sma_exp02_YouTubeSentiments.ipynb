# %%
import requests

# %%
video_id = "l-nMKJ5J3Uc"

api_key =  "AIzaSyCJF6Ljcay6oDQ1Bv-oO9ewD55Vktn_FEQ"

# %%
video_info_url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet&id={video_id}&key={api_key}"
video_info_response = requests.get(video_info_url)
video_info_data = video_info_response.json()

print(video_info_data)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'cAeJdcwEec5A074l7b_OiUeUc0Y', 'items': [{'kind': 'youtube#video', 'etag': 'u4-XQ9ckrQCzaLXq9HWCeCLdJV0', 'id': 'l-nMKJ5J3Uc', 'snippet': {'publishedAt': '2024-04-20T15:59:59Z', 'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA', 'title': 'Ages 1 - 100 Decide Who Wins $250,000', 'description': 'I can’t believe who they picked\nThanks Top Troops for sponsoring this video. Download Top Troops at https://toptroops.onelink.me/JHnC/mrbeast or scan the QR code to get a FREE special Starter Pack for a limited time\n\nThanks Samsung for the Tab S9s - the Galaxy AI features are cool too: https://smsng.us/MrBTabS9\n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nAlso thank you Concept Pixel for the LED Walls,it looked great!\n\xa0www.conceptpixels.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/l-nMKJ5J3Uc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/l-nMKJ5J3Uc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/l-nMKJ5J3Uc/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/l-nMKJ5J3Uc/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/l-nMKJ5J3Uc/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'MrBeast', 'categoryId': '24', 'liveBroadcastContent': 'none', 'defaultLanguage': 'en', 'localized': {'title': 'Ages 1 - 100 Decide Who Wins $250,000', 'description': 'I can’t believe who they picked\nThanks Top Troops for sponsoring this video. Download Top Troops at https://toptroops.onelink.me/JHnC/mrbeast or scan the QR code to get a FREE special Starter Pack for a limited time\n\nThanks Samsung for the Tab S9s - the Galaxy AI features are cool too: https://smsng.us/MrBTabS9\n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nAlso thank you Concept Pixel for the LED Walls,it looked great!\n\xa0www.conceptpixels.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------'}, 'defaultAudioLanguage': 'en'}}], 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %% [markdown]
# ***Retrieve Youtube Video Comments***

# %%
comments_url = f"https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={video_id}&key={api_key}"
comments_response = requests.get(comments_url)
comments_data = comments_response.json()

comments_data
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'QQ4MRZv-c2LMrzuJpmzuOUJpeNk',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNLZ2dHQUFTQlFpSElCZ0FFZ1VJaUNBWUFCSUZDSWtnR0FBU0JRaWRJQmdCR0FBaURRb0xDSjNIdExFR0VNakI2QXM=',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'Nz6ClXeinr5UBH0y5DqS0OZr57Y',
#    'id': 'UgwD2Uup_GluBePhdYF4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'wwyKQk_nqx5pz_n3mhC0lW4I5TE',
#      'id': 'UgwD2Uup_GluBePhdYF4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'LONGER VIDEOS WITH STORYTELLING IS HERE',
#       'textOriginal': 'LONGER VIDEOS WITH STORYTELLING IS HERE',
#       'authorDisplayName': '@MrBeast',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/fxGKYucJAVme-Yz4fsdCroCFCrANWqw0ql4GYuvx8Uq4l_euNJHgE-w9MTkLQA805vWCi-kE0g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@MrBeast',
#       'authorChannelId': {'value': 'UCX6OQ3DkcsbYNE6H8uQQuVA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 199214,
#       'publishedAt': '2024-04-20T17:00:36Z',
#       'updatedAt': '2024-04-20T17:00:36Z'}},
#     'canReply': False,
#     'totalReplyCount': 750,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nz3KQ_sx7thrOiZyD2FxyDnF_7Y',
#    'id': 'UgzhgBjsd71Y09JVfQd4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'U2mgZFyLhqEgxvjDrc04QeVj-FQ',
#      'id': 'UgzhgBjsd71Y09JVfQd4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '7 said  I will buy you Roblox I promise if you get out of your cube',
#       'textOriginal': '7 said  I will buy you Roblox I promise if you get out of your cube',
#       'authorDisplayName': '@yigglewiggle',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/8n80BugkLE5zJAQ7kF_mp2628K4lBUv0DOZpn_gk7VfAq8CSAiPT3HiF49vvGSo_es0wYwWbFA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@yigglewiggle',
#       'authorChannelId': {'value': 'UCwoqltK7ezsL9LCioYtA0qA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:15:43Z',
#       'updatedAt': '2024-04-27T16:15:43Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'TSy9qVXNhl5iRf5hqi473DExSqQ',
#    'id': 'Ugws5pxLrhetPXmXLCh4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'vzh4jnv9n-LSkZilP43wCyG7sAo',
#      'id': 'Ugws5pxLrhetPXmXLCh4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Wish I was in a mr beast vid',
#       'textOriginal': 'Wish I was in a mr beast vid',
#       'authorDisplayName': '@MenzaTengoku',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/FvGjgRD0SNmMvRflgYBRbXexD34yIB_fykHi7ohrxJqVvDoDuXLoANsjzoOUw7ZX0k4L_60N=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@MenzaTengoku',
#       'authorChannelId': {'value': 'UCZ8KZFv_W1I0lkwB_8NxUSQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:15:04Z',
#       'updatedAt': '2024-04-27T16:15:04Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'JuSdcKtBfqkz3nwsmtxeDxj-4rA',
#    'id': 'Ugz2BhS8ozcpwOmj7WB4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'zkmL8oRgYK3iyCh-8dGjnX7g6Zw',
#      'id': 'Ugz2BhS8ozcpwOmj7WB4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Best video in a while',
#       'textOriginal': 'Best video in a while',
#       'authorDisplayName': '@stephanbuist5045',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nFtL15WInEAXPuSlnB-FVMJw7RHG1TfuUQNVR2KloHl24=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@stephanbuist5045',
#       'authorChannelId': {'value': 'UCUdaikmk52ZvrrYdvEVqVcA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:14:56Z',
#       'updatedAt': '2024-04-27T16:14:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'jxj4zgf1bXb9ULnCobaNYeNcVVw',
#    'id': 'UgypV9QIDHhJaUwzTn94AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '6R9k_PQaWVn1dr9Q2m2AsriCB-I',
#      'id': 'UgypV9QIDHhJaUwzTn94AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '42 was a literal puppeteer, just absolutely controlling 43. And 43 was just a puppet who somewhat couldn’t think for herself. Glad 58 ended the cycle though I mean that was pure heroism. 😅',
#       'textOriginal': '42 was a literal puppeteer, just absolutely controlling 43. And 43 was just a puppet who somewhat couldn’t think for herself. Glad 58 ended the cycle though I mean that was pure heroism. 😅',
#       'authorDisplayName': '@pqwprint',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/sbM0nR5NzRWnloumi4-IcTG9KVAbDv1WgUgW5H4f-NVUMCEohlmpmC9NgAjwgX36yGyraiwRAII=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@pqwprint',
#       'authorChannelId': {'value': 'UCFrN59GYKXn3HPpkvTn5Sow'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:14:50Z',
#       'updatedAt': '2024-04-27T16:14:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'GRLiQVNewyNfwDzzuTitJ3yVuaM',
#    'id': 'Ugzvge1_ywT95RXac7N4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'DsbEPFXYtiCECK5dFVDDbVI2Na4',
#      'id': 'Ugzvge1_ywT95RXac7N4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '40s are evil mostly 43 and 42.',
#       'textOriginal': '40s are evil mostly 43 and 42.',
#       'authorDisplayName': '@alexplays1237',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ygXwwMTQ4I9YHaIO3qtvMbkVdxzYRkAJImDGa-EXOKOtiHAhECRzWvF6IdeMIpCTY5ZFpSWi3g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@alexplays1237',
#       'authorChannelId': {'value': 'UC72EaYE8uUWMVazu3dBcFgw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:14:44Z',
#       'updatedAt': '2024-04-27T16:14:44Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'rjMWrJgw7sLou3CYzBpBC4JmR_0',
#    'id': 'UgyPq2CvPLtWx1p8rzV4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'NpAue0x-BI33lOKB2Zti5wokLd4',
#      'id': 'UgyPq2CvPLtWx1p8rzV4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Longer vids are always better brother.',
#       'textOriginal': 'Longer vids are always better brother.',
#       'authorDisplayName': '@Tyson.m.o.h.r.',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kfFbqiD72rTzjB831be3qwP2A7yOUqn6pXMXXT2PE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Tyson.m.o.h.r.',
#       'authorChannelId': {'value': 'UCv3vsm1lfaJ72HahW-4zv0A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:14:40Z',
#       'updatedAt': '2024-04-27T16:14:40Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5OIPn_ic0xKf5AIsWH604qH-dtw',
#    'id': 'UgxEZMJNWWof54YNlGh4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'iEZI3gkjfz-gWz8_EXt4oDAQt3c',
#      'id': 'UgxEZMJNWWof54YNlGh4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'I’m fighting who ever eliminates me',
#       'textOriginal': 'I’m fighting who ever eliminates me',
#       'authorDisplayName': '@bigboydarthmaul7257',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/t9MYU6BCJvV9zmDOhWTIL_2JdAQLYNLXkmSMxlRMmk5ghkij3C1bYswDT33ZGJv_wHkaSAoy=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@bigboydarthmaul7257',
#       'authorChannelId': {'value': 'UCbKFoVJCibBS9_6dpCuDbQA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:14:30Z',
#       'updatedAt': '2024-04-27T16:14:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'w0nrOPWZ6PVkGdtaSv0wILjENSM',
#    'id': 'UgwxLUSYg-Ez998LY3V4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '15enp3lT46tcb_S4-q2dlUPV0VM',
#      'id': 'UgwxLUSYg-Ez998LY3V4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Mrbeast slowly turning his channel into squid <br>Games',
#       'textOriginal': 'Mrbeast slowly turning his channel into squid \nGames',
#       'authorDisplayName': '@yigglewiggle',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/8n80BugkLE5zJAQ7kF_mp2628K4lBUv0DOZpn_gk7VfAq8CSAiPT3HiF49vvGSo_es0wYwWbFA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@yigglewiggle',
#       'authorChannelId': {'value': 'UCwoqltK7ezsL9LCioYtA0qA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:14:28Z',
#       'updatedAt': '2024-04-27T16:14:28Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'A0EK8ESvCZARZpvfeSXuDO48QMs',
#    'id': 'UgywNkItjoYr29D2jW14AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'krp6pZSoCQrtAK6Zy0XwshpUDBc',
#      'id': 'UgywNkItjoYr29D2jW14AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Me cae mal 43 and 42',
#       'textOriginal': 'Me cae mal 43 and 42',
#       'authorDisplayName': '@user-jw5sy9vj1m',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n5CE76MVQkMhu6a4iK8az9kQPv_kPr-iuQ5nXhdG29qrENWaHeBnsbgnZdiKIuS-Wfkw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-jw5sy9vj1m',
#       'authorChannelId': {'value': 'UCPfuF0eoyesWwgwR-sOM2Kg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:14:11Z',
#       'updatedAt': '2024-04-27T16:14:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Mqq5B0yMfey8jbZihsbWcr9_Wss',
#    'id': 'Ugx2qRWeaAmj_EicWl94AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'pqtsVaeOgkeAjhgrzlCfA2OILlE',
#      'id': 'Ugx2qRWeaAmj_EicWl94AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '&quot;Now is not the time to develop a heart&quot;🥶',
#       'textOriginal': '"Now is not the time to develop a heart"🥶',
#       'authorDisplayName': '@doodleee3',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-vM9OcSV-m5OFCsItaYgJB1riSIDgLWnRv7qm5dERyBzIDtxXq2HI-zQiMba1zNwXF0Oo6viEg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@doodleee3',
#       'authorChannelId': {'value': 'UCoWwR5j6BL88aFRlC26dWbg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-04-27T16:13:49Z',
#       'updatedAt': '2024-04-27T16:13:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'U_X3zT2cq1__47Dv1RqKXZ3VMSg',
#    'id': 'UgyeRHLktYc1z-itIVp4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'cCU3nS2l9NlAlU_9wtrhmpgzXpE',
#      'id': 'UgyeRHLktYc1z-itIVp4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '❤❤❤❤🎉🎉🎉',
#       'textOriginal': '❤❤❤❤🎉🎉🎉',
#       'authorDisplayName': '@user-ud2nl3yo6i',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_laKiAQG6APgun5ka2vr77FM6nHj6zegkYUZsMSwWKDpioFAo0JNiuSsgQgZcAW5aHBYg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-ud2nl3yo6i',
#       'authorChannelId': {'value': 'UCPCikkRaDzFa9Ym09ohL8Kg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:13:32Z',
#       'updatedAt': '2024-04-27T16:13:32Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'MvRQtKTh0RPKmptzNcoFMpq69IM',
#    'id': 'UgyavEhFhCY1tjMIzH54AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '40RnAdq-wfuSl7UDKZ2KMo1UQ2A',
#      'id': 'UgyavEhFhCY1tjMIzH54AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '96years old is amazing 😮',
#       'textOriginal': '96years old is amazing 😮',
#       'authorDisplayName': '@user-jy2ry8lc9s',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/1JTiThU4kXFNZBxhq-ZBrb-VJPg2yiNdGyescV13ziePJIpBxkukaODfLxJYDxieKZafvWFo=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-jy2ry8lc9s',
#       'authorChannelId': {'value': 'UCUuqM6cPg4bXWxOU63geQQw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:13:24Z',
#       'updatedAt': '2024-04-27T16:13:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'a5QjWYbbNNSbiLol9xnXIgC6Vxo',
#    'id': 'UgwcCOhAwlq4-wHav6R4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '6XIuTbN8mvfO-5ONwf5uADhFnF0',
#      'id': 'UgwcCOhAwlq4-wHav6R4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '42 is such a cartoon Villain 😂😂😂😂',
#       'textOriginal': '42 is such a cartoon Villain 😂😂😂😂',
#       'authorDisplayName': '@yigglewiggle',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/8n80BugkLE5zJAQ7kF_mp2628K4lBUv0DOZpn_gk7VfAq8CSAiPT3HiF49vvGSo_es0wYwWbFA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@yigglewiggle',
#       'authorChannelId': {'value': 'UCwoqltK7ezsL9LCioYtA0qA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:12:29Z',
#       'updatedAt': '2024-04-27T16:12:29Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '6TuYrfICks6M400EbdspO0-WHAA',
#    'id': 'UgzQN10bJFaZYlbnnpR4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gEr-6A562psUXT5iyz9GQf56POA',
#      'id': 'UgzQN10bJFaZYlbnnpR4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'i cried because of the 40s',
#       'textOriginal': 'i cried because of the 40s',
#       'authorDisplayName': '@thebiggestswiftieever-yu9jp',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lBa1TOTI6Ac3TsIzXO3aaHUH3mJSI6jMbDhLzZGIf7y04pPVOxsZTsJIILEIqd9MBymg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@thebiggestswiftieever-yu9jp',
#       'authorChannelId': {'value': 'UCwojoaD4RF8Lterwvz1JA8g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:12:25Z',
#       'updatedAt': '2024-04-27T16:12:25Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'A_jWxcU_BvpnTFoQ2QDqY3_-634',
#    'id': 'UgzoQmwT239Xyp6iXCN4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'MGJaoocuXtcEzRuCS6qDLQz45rw',
#      'id': 'UgzoQmwT239Xyp6iXCN4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'I didn&#39;t even notice that this video was 40 mins long :D Felt way shorter',
#       'textOriginal': "I didn't even notice that this video was 40 mins long :D Felt way shorter",
#       'authorDisplayName': '@MsYolost',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n92-q9pcQUtF6xngrbcwDjHuLJfNYFurNg9NgvJHk=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@MsYolost',
#       'authorChannelId': {'value': 'UCNTgLpWeSGFARu4PNFSJkAQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:12:13Z',
#       'updatedAt': '2024-04-27T16:12:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 't35ldnbiEC7AkoK1sBbICjvVr_Y',
#    'id': 'UgydFuPlmzUwQ74Nnax4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'GiwGVQLf6wzXYiCoOi3cUgYc9OY',
#      'id': 'UgydFuPlmzUwQ74Nnax4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Esse foi o vídeo que eu mais odiei',
#       'textOriginal': 'Esse foi o vídeo que eu mais odiei',
#       'authorDisplayName': '@richardrafaello9914',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/fpbchPV5PjjtfZiWG-T5CrW4g62up0k8K-aZqrCwvooFXoo30QMxP2H-ifsF70qMyveWjQUJ2g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@richardrafaello9914',
#       'authorChannelId': {'value': 'UC0kU2YXN4GERPWJy8S1ycmg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:12:06Z',
#       'updatedAt': '2024-04-27T16:12:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '9kgxxzAo5kW2QE8RQ4UxBSliwP4',
#    'id': 'UgygSaUGMivX7_HnzAx4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'wCq0ez1nunTNPLOb0-fL58p1J0I',
#      'id': 'UgygSaUGMivX7_HnzAx4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'dis is psychological torture',
#       'textOriginal': 'dis is psychological torture',
#       'authorDisplayName': '@Dipslox',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n-n8jD85FkaEZD5mm2AXjc835O8pBkpEwO9SQrkNEODqQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Dipslox',
#       'authorChannelId': {'value': 'UCZONmKelR5cnhijiGJhX14g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:11:27Z',
#       'updatedAt': '2024-04-27T16:11:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'BDqQE5Jvw_n8lR14s4jSaTMBiI8',
#    'id': 'UgywR81tMEPOnLBMGWt4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'juG_iK5w0OQZwE8RwOtPERzscgI',
#      'id': 'UgywR81tMEPOnLBMGWt4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Hey what I want you to do is go to time stamp <br>Challenge audio truck to',
#       'textOriginal': 'Hey what I want you to do is go to time stamp \nChallenge audio truck to',
#       'authorDisplayName': '@yigglewiggle',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/8n80BugkLE5zJAQ7kF_mp2628K4lBUv0DOZpn_gk7VfAq8CSAiPT3HiF49vvGSo_es0wYwWbFA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@yigglewiggle',
#       'authorChannelId': {'value': 'UCwoqltK7ezsL9LCioYtA0qA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:11:20Z',
#       'updatedAt': '2024-04-27T16:11:20Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'fvqba7S-FV5ztZRBKXWW37HF1wc',
#    'id': 'UgwLm4Lgc0VEUC13f854AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'CQesnYOqRunW6Czm005srjCoGhw',
#      'id': 'UgwLm4Lgc0VEUC13f854AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'good job no that I was sad in the end',
#       'textOriginal': 'good job no that I was sad in the end',
#       'authorDisplayName': '@Cookie-lv1kj',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/6ZVbpYFu9HQo9cVe1zpHRYikOs6SPEExcRdW7whSUwgjc8WhGTUKTuVzVHRyjGQe-kpJo_DlVA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Cookie-lv1kj',
#       'authorChannelId': {'value': 'UCTSPQ9B849sFa7mU8kxjqNQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-27T16:11:09Z',
#       'updatedAt': '2024-04-27T16:11:09Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
#extract the comment

comments = [item["snippet"]["topLevelComment"]["snippet"]["textOriginal"] for item in comments_data["items"]]

print(comments)
# Out:
# ['LONGER VIDEOS WITH STORYTELLING IS HERE', '7 said  I will buy you Roblox I promise if you get out of your cube', 'Wish I was in a mr beast vid', 'Best video in a while', '42 was a literal puppeteer, just absolutely controlling 43. And 43 was just a puppet who somewhat couldn’t think for herself. Glad 58 ended the cycle though I mean that was pure heroism. 😅', '40s are evil mostly 43 and 42.', 'Longer vids are always better brother.', 'I’m fighting who ever eliminates me', 'Mrbeast slowly turning his channel into squid \nGames', 'Me cae mal 43 and 42', '"Now is not the time to develop a heart"🥶', '❤❤❤❤🎉🎉🎉', '96years old is amazing 😮', '42 is such a cartoon Villain 😂😂😂😂', 'i cried because of the 40s', "I didn't even notice that this video was 40 mins long :D Felt way shorter", 'Esse foi o vídeo que eu mais odiei', 'dis is psychological torture', 'Hey what I want you to do is go to time stamp \nChallenge audio truck to', 'good job no that I was sad in the end']

# %% [markdown]
# ***Sentiments Analysis Of the Comments***

# %%
from textblob import TextBlob

# %%
def get_comment_sentiment(comment):
    analysis = TextBlob(comment)

    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'nagative'

for comment in comments:
    print(f"{comment}: {get_comment_sentiment(comment)}")

comment_list = []

sentiment_list =[]

for comment in comments:
    sentiment = get_comment_sentiment(comment)
    comment_list.append(comment)
    sentiment_list.append(sentiment)
    print(f"{comment} : {sentiment}")
# Out:
# LONGER VIDEOS WITH STORYTELLING IS HERE: neutral
# 7 said  I will buy you Roblox I promise if you get out of your cube: neutral
# Wish I was in a mr beast vid: neutral
# Best video in a while: positive
# 42 was a literal puppeteer, just absolutely controlling 43. And 43 was just a puppet who somewhat couldn’t think for herself. Glad 58 ended the cycle though I mean that was pure heroism. 😅: positive
# 40s are evil mostly 43 and 42.: nagative
# Longer vids are always better brother.: positive
# I’m fighting who ever eliminates me: neutral
# Mrbeast slowly turning his channel into squid
# Games: nagative
# Me cae mal 43 and 42: neutral
# "Now is not the time to develop a heart"🥶: neutral
# ❤❤❤❤🎉🎉🎉: neutral
# 96years old is amazing 😮: positive
# 42 is such a cartoon Villain 😂😂😂😂: neutral
# i cried because of the 40s: neutral
# I didn't even notice that this video was 40 mins long :D Felt way shorter: positive
# Esse foi o vídeo que eu mais odiei: neutral
# dis is psychological torture: neutral
# Hey what I want you to do is go to time stamp
# Challenge audio truck to: neutral
# good job no that I was sad in the end: positive
# LONGER VIDEOS WITH STORYTELLING IS HERE : neutral
# 7 said  I will buy you Roblox I promise if you get out of your cube : neutral
# Wish I was in a mr beast vid : neutral
# Best video in a while : positive
# 42 was a literal puppeteer, just absolutely controlling 43. And 43 was just a puppet who somewhat couldn’t think for herself. Glad 58 ended the cycle though I mean that was pure heroism. 😅 : positive
# 40s are evil mostly 43 and 42. : nagative
# Longer vids are always better brother. : positive
# I’m fighting who ever eliminates me : neutral
# Mrbeast slowly turning his channel into squid
# Games : nagative
# Me cae mal 43 and 42 : neutral
# "Now is not the time to develop a heart"🥶 : neutral
# ❤❤❤❤🎉🎉🎉 : neutral
# 96years old is amazing 😮 : positive
# 42 is such a cartoon Villain 😂😂😂😂 : neutral
# i cried because of the 40s : neutral
# I didn't even notice that this video was 40 mins long :D Felt way shorter : positive
# Esse foi o vídeo que eu mais odiei : neutral
# dis is psychological torture : neutral
# Hey what I want you to do is go to time stamp
# Challenge audio truck to : neutral
# good job no that I was sad in the end : positive

# %%
import pandas as pd

comment_list

sentiment_list

sentiment_df = pd.DataFrame({"Comments": comment_list,"Sentiment": sentiment_list})

sentiment_df

sentiment_df.to_csv("YouTube_Comments_Sentiment.csv")  #gets saved to current folder

# %%
sentiment_df
# Out:
#                                              Comments Sentiment
# 0             LONGER VIDEOS WITH STORYTELLING IS HERE   neutral
# 1   7 said  I will buy you Roblox I promise if you...   neutral
# 2                        Wish I was in a mr beast vid   neutral
# 3                               Best video in a while  positive
# 4   42 was a literal puppeteer, just absolutely co...  positive
# 5                      40s are evil mostly 43 and 42.  nagative
# 6              Longer vids are always better brother.  positive
# 7                 I’m fighting who ever eliminates me   neutral
# 8   Mrbeast slowly turning his channel into squid ...  nagative
# 9                                Me cae mal 43 and 42   neutral
# 10          "Now is not the time to develop a heart"🥶   neutral
# 11                                            ❤❤❤❤🎉🎉🎉   neutral
# 12                           96years old is amazing 😮  positive
# 13                  42 is such a cartoon Villain 😂😂😂😂   neutral
# 14                         i cried because of the 40s   neutral
# 15  I didn't even notice that this video was 40 mi...  positive
# 16                 Esse foi o vídeo que eu mais odiei   neutral
# 17                       dis is psychological torture   neutral
# 18  Hey what I want you to do is go to time stamp ...   neutral
# 19              good job no that I was sad in the end  positive
